# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import openpyxl

# %%
df = pd.read_csv("dentists.csv", index_col=0)

# %%
df
# Out:
#                            Name                      Website            Phone  \
# 0    New York General Dentistry  newyorkgeneraldentistry.com  +1 212-838-0842
# 1              Pearl Dental NYC           pearldentalnyc.com  +1 212-344-9317
# 2      Rockefeller Dental Group   rockefellerdentalgroup.com  +1 212-246-9070
# 3        New York Dental Office      newyorkdentaloffice.com  +1 212-548-3261
# 4                   FiDi Dental            fididentalnyc.com  +1 212-742-2070
# ..                          ...                          ...              ...
# 115        Billings Dental Care     billingsdentalcareny.com  +1 845-223-3966
# 116        Billings Dental Care     billingsdentalcareny.com  +1 845-223-3966
# 117                Aspen Dental              aspendental.com  +1 315-445-9400
# 118                Aspen Dental              aspendental.com  +1 315-445-9400
# 119           JBL New York City                   jblnyc.com  +1 212-734-6111
#
# ...

# %%
df.duplicated().sum()
# Out:
# 22

# %%
names = df["Name"]
df[names.isin(names[names.duplicated()])].sort_values("Name")
# Out:
#                                                   Name  \
# 57                                      209 NYC Dental
# 37                                      209 NYC Dental
# 47                     Aesthetic Dentistry of New York
# 27                     Aesthetic Dentistry of New York
# 98                                        Aspen Dental
# 94                                        Aspen Dental
# 89                                        Aspen Dental
# 117                                       Aspen Dental
# 118                                       Aspen Dental
# 116                               Billings Dental Care
# 115                               Billings Dental Care
# 25                                    Brite Dental Spa
# 45                                    Brite Dental Spa
# 20                                  Central Ave Dental
# 40                                  Central Ave Dental
# 69                              Columbus Circle Dental
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                            Name                      Website            Phone  \
# 0    New York General Dentistry  newyorkgeneraldentistry.com  +1 212-838-0842
# 1              Pearl Dental NYC           pearldentalnyc.com  +1 212-344-9317
# 2      Rockefeller Dental Group   rockefellerdentalgroup.com  +1 212-246-9070
# 3        New York Dental Office      newyorkdentaloffice.com  +1 212-548-3261
# 4                   FiDi Dental            fididentalnyc.com  +1 212-742-2070
# ..                          ...                          ...              ...
# 113                      Dental                          NaN              NaN
# 115        Billings Dental Care     billingsdentalcareny.com  +1 845-223-3966
# 117                Aspen Dental              aspendental.com  +1 315-445-9400
# 118                Aspen Dental              aspendental.com  +1 315-445-9400
# 119           JBL New York City                   jblnyc.com  +1 212-734-6111
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## save to excel

# %%
excel_file = pd.ExcelWriter("dentists.xlsx")
df.to_excel(excel_file)
excel_file.save()

# %% [markdown]
# ## save as csv

# %%
df.to_csv("dentists.csv")
